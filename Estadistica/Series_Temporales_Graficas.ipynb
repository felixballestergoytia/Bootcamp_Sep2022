# %%
from pandas_datareader import data as web
import pandas as pd
import numpy as np
import datetime

# %%
fecha=datetime.datetime(year=2022,month=10,day=28)

# %%
fecha.strftime("%y")
# Out:
# '22'

# %%
fecha.strftime("%d")
# Out:
# '28'

# %%
fecha.strftime("%m")
# Out:
# '10'

# %%
fecha.strftime("%A")
# Out:
# 'Friday'

# %%
fecha.strftime("%a")
# Out:
# 'Fri'

# %%
fecha.strftime("%w")
# Out:
# '5'

# %% [markdown]
#     * **%a** Abreviación Día de la semana
#     * **%A** Día de la semana
#     * **%d** Día del mes...

# %%
fechanp=np.array('2022-10-28',dtype=np.datetime64)

# %%
fechanp+3
# Out:
# numpy.datetime64('2022-10-31')

# %%
fechanp+np.arange(20)
# Out:
# array(['2022-10-28', '2022-10-29', '2022-10-30', '2022-10-31',
#        '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#        '2022-11-05', '2022-11-06', '2022-11-07', '2022-11-08',
#        '2022-11-09', '2022-11-10', '2022-11-11', '2022-11-12',
#        '2022-11-13', '2022-11-14', '2022-11-15', '2022-11-16'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2022-10-28')
# Out:
# numpy.datetime64('2022-10-28')

# %%
np.datetime64('2022-10-28 09:00')
# Out:
# numpy.datetime64('2022-10-28T09:00')

# %%
np.datetime64('2022-10-28 00:00:09.64','ns')
# Out:
# numpy.datetime64('2022-10-28T00:00:09.640000000')

# %%
fechapd=pd.to_datetime("28th of October,2022")

# %%
fechapd.strftime("%A")
# Out:
# 'Friday'

# %%
fechapd + pd.to_timedelta(np.arange(12),'D')
# Out:
# DatetimeIndex(['2022-10-28', '2022-10-29', '2022-10-30', '2022-10-31',
#                '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-05', '2022-11-06', '2022-11-07', '2022-11-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
fechapd + pd.to_timedelta(np.arange(12),'m')
# Out:
# DatetimeIndex(['2022-10-28 00:00:00', '2022-10-28 00:01:00',
#                '2022-10-28 00:02:00', '2022-10-28 00:03:00',
#                '2022-10-28 00:04:00', '2022-10-28 00:05:00',
#                '2022-10-28 00:06:00', '2022-10-28 00:07:00',
#                '2022-10-28 00:08:00', '2022-10-28 00:09:00',
#                '2022-10-28 00:10:00', '2022-10-28 00:11:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start='2022-10-28',periods=12,freq='D')
# Out:
# DatetimeIndex(['2022-10-28', '2022-10-29', '2022-10-30', '2022-10-31',
#                '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-05', '2022-11-06', '2022-11-07', '2022-11-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2022-10-28',periods=12,freq='M')
# Out:
# DatetimeIndex(['2022-10-31', '2022-11-30', '2022-12-31', '2023-01-31',
#                '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31',
#                '2023-06-30', '2023-07-31', '2023-08-31', '2023-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
meses=pd.date_range(start='2022-10-28',periods=12,freq='M')

# %%
print(meses.min())
print(meses.max())
# Out:
# 2022-10-31 00:00:00
# 2023-09-30 00:00:00

# %%
comienzo = datetime.datetime(1991,1,1)
final = datetime.datetime(2020,12,31)
df = web.DataReader("AAPL",
              start=comienzo,
              end=final,
              data_source="yahoo")

# %%
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 1991
()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 1991-03-29       NaN       NaN       NaN       NaN          NaN        NaN
# 1991-06-28  0.379464  0.359375  0.377232  0.370536  226643200.0   0.300666
# 1991-09-30  0.444196  0.437500  0.439732  0.441964   63201600.0   0.359435
# 1991-12-31  0.517857  0.500000  0.512277  0.503348  134030400.0   0.410341
# 1992-03-31  0.533482  0.517857  0.520089  0.520089  212632000.0   0.424781

# %%
df["Variacion_High"]=df["High"]/df["High"].shift(1)-1

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 1991-01-02    0.392857    0.375000    0.381696    0.388393  154985600.0
# 1991-01-03    0.395089    0.383929    0.388393    0.383929  150180800.0
# 1991-01-04    0.395089    0.383929    0.383929    0.386161  141523200.0
# 1991-01-07    0.404018    0.383929    0.383929    0.386161  310800000.0
# 1991-01-08    0.391741    0.379464    0.390625    0.386161  218691200.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
#
#              Adj Close  Variacion_High
# Date
# 1991-01-02    0.313691             NaN
# 1991-01-03    0.310086        0.005681
# 1991-01-04    0.311889        0.000000
# 1991-01-07    0.311889        0.022600
# 1991-01-08    0.311889       -0.030387
# ...                ...             ...
# 2020-12-24  130.620911        0.007778
# 2020-12-28  135.292648        0.029072
# 2020-12-29  133.491241        0.010558
# 2020-12-30  132.353027       -0.020174
# 2020-12-31  131.333542       -0.009192
#
# [7559 rows x 7 columns]

# %%
df["Variacion_High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Medias_Moviles_High"]=df["High"].rolling(window=5).mean()

# %%
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close  \
# Date
# 1991-01-02  0.392857  0.375000  0.381696  0.388393  154985600.0   0.313691
# 1991-01-03  0.395089  0.383929  0.388393  0.383929  150180800.0   0.310086
# 1991-01-04  0.395089  0.383929  0.383929  0.386161  141523200.0   0.311889
# 1991-01-07  0.404018  0.383929  0.383929  0.386161  310800000.0   0.311889
# 1991-01-08  0.391741  0.379464  0.390625  0.386161  218691200.0   0.311889
#
#             Variacion_High  Medias_Moviles_High
# Date
# 1991-01-02             NaN                  NaN
# 1991-01-03        0.005681                  NaN
# 1991-01-04        0.000000                  NaN
# 1991-01-07        0.022600                  NaN
# 1991-01-08       -0.030387             0.395759

# %%
df["Diferencia_Volumen"]=df["Volume"].diff(periods=1)

# %%
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close  \
# Date
# 1991-01-02  0.392857  0.375000  0.381696  0.388393  154985600.0   0.313691
# 1991-01-03  0.395089  0.383929  0.388393  0.383929  150180800.0   0.310086
# 1991-01-04  0.395089  0.383929  0.383929  0.386161  141523200.0   0.311889
# 1991-01-07  0.404018  0.383929  0.383929  0.386161  310800000.0   0.311889
# 1991-01-08  0.391741  0.379464  0.390625  0.386161  218691200.0   0.311889
#
#             Variacion_High  Medias_Moviles_High  Diferencia_Volumen
# Date
# 1991-01-02             NaN                  NaN                 NaN
# 1991-01-03        0.005681                  NaN          -4804800.0
# 1991-01-04        0.000000                  NaN          -8657600.0
# 1991-01-07        0.022600                  NaN         169276800.0
# 1991-01-08       -0.030387             0.395759         -92108800.0

# %%
df_Ch["Diferencia_Volumen"]=df_Ch["Volume"].diff(periods=1)

# %%
df_Ch.head()
# Out:
#        High       Low      Open     Close       Volume  Adj Close  \
# 0  0.392857  0.375000  0.381696  0.388393  154985600.0   0.313691
# 1  0.395089  0.383929  0.388393  0.383929  150180800.0   0.310086
# 2  0.395089  0.383929  0.383929  0.386161  141523200.0   0.311889
# 3  0.404018  0.383929  0.383929  0.386161  310800000.0   0.311889
# 4  0.391741  0.379464  0.390625  0.386161  218691200.0   0.311889
#
#    Diferencia_Volumen
# 0                 NaN
# 1          -4804800.0
# 2          -8657600.0
# 3         169276800.0
# 4         -92108800.0

# %%
df_Ch["Diferencia_Volumen"].plot()
# Out:
# <AxesSubplot:>

# %%
import statsmodels.api as sm

# %%
sm.tsa.filters.hpfilter(df["Adj Close"])
# Out:
# (Date
#  1991-01-02    0.008232
#  1991-01-03   -0.000078
#  1991-01-04   -0.002986
#  1991-01-07   -0.007706
#  1991-01-08   -0.012439
#                  ...
#  2020-12-24    0.361338
#  2020-12-28    4.263755
#  2020-12-29    1.695953
#  2020-12-30   -0.206043
#  2020-12-31   -1.988068
#  Name: Adj Close_cycle, Length: 7559, dtype: float64,
#  Date
#  1991-01-02      0.305460
#  1991-01-03      0.310164
#  1991-01-04      0.314874
#  1991-01-07      0.319594
#  1991-01-08      0.324328
#                   ...
#  2020-12-24    130.259572
#  2020-12-28    131.028893
#  2020-12-29    131.795289
#  2020-12-30    132.559071
#  2020-12-31    133.321610
#  Name: Adj Close_trend, Length: 7559, dtype: float64)

# %%
ciclo,tendecia=sm.tsa.filters.hpfilter(df["Adj Close"])

# %%
df["tendecia"]=tendecia

# %%
df[["Adj Close","tendecia"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df["Medias_Moviles_Adj_Close"]=df["Adj Close"].rolling(window=5).mean()

# %%
df[["Adj Close","tendecia","Medias_Moviles_Adj_Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sm.tsa.seasonal_decompose(df["Adj Close"],model="additive",period=30).plot();

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x=df["Volume"],bins=[])
# Out:
# (array([6.559e+03, 8.510e+02, 1.210e+02, 2.100e+01, 4.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.3968000e+06, 7.4432120e+08, 1.4862456e+09, 2.2281700e+09,
#         2.9700944e+09, 3.7120188e+09, 4.4539432e+09, 5.1958676e+09,
#         5.9377920e+09, 6.6797164e+09, 7.4216408e+09]),
#  <BarContainer object of 10 artists>)

# %%
maximo=df["Volume"].max()

# %%
maximo
# Out:
# 7421640800.0

# %%
minimo=df["Volume"].min()

# %%
minimo
# Out:
# 2396800.0

# %%
(maximo-minimo)/10
# Out:
# 741924400.0

# %%
np.arange(minimo,maximo,(maximo-minimo)/10)
# Out:
# array([2.3968000e+06, 7.4432120e+08, 1.4862456e+09, 2.2281700e+09,
#        2.9700944e+09, 3.7120188e+09, 4.4539432e+09, 5.1958676e+09,
#        5.9377920e+09, 6.6797164e+09])

# %%
plt.hist(x=df["Volume"],bins=np.arange(minimo,maximo,(maximo-minimo)/100));

# %%
df["Anyo"]=df.index.strftime("%Y")

# %%
df.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close  \
# Date
# 1991-01-02  0.392857  0.375000  0.381696  0.388393  154985600.0   0.313691
# 1991-01-03  0.395089  0.383929  0.388393  0.383929  150180800.0   0.310086
# 1991-01-04  0.395089  0.383929  0.383929  0.386161  141523200.0   0.311889
# 1991-01-07  0.404018  0.383929  0.383929  0.386161  310800000.0   0.311889
# 1991-01-08  0.391741  0.379464  0.390625  0.386161  218691200.0   0.311889
#
#             Variacion_High  Medias_Moviles_High  Diferencia_Volumen  tendecia  \
# Date
# 1991-01-02             NaN                  NaN                 NaN  0.305460
# 1991-01-03        0.005681                  NaN          -4804800.0  0.310164
# 1991-01-04        0.000000                  NaN          -8657600.0  0.314874
# 1991-01-07        0.022600                  NaN         169276800.0  0.319594
# 1991-01-08       -0.030387             0.395759         -92108800.0  0.324328
#
#             Medias_Moviles_Adj_Close  Anyo
# Date
# 1991-01-02                       NaN  1991
# 1991-01-03                       NaN  1991
# 1991-01-04                       NaN  1991
# 1991-01-07                       NaN  1991
# 1991-01-08                  0.311889  1991

# %%
df.groupby(["Anyo"])["High"].mean().plot.barh()
# Out:
# <AxesSubplot:ylabel='Anyo'>

# %%
df.groupby(["Anyo"])["High"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Anyo'>

# %%
df.groupby(["Anyo"])["High"].mean().plot.line()
# Out:
# <AxesSubplot:xlabel='Anyo'>

# %%
df.groupby(["Anyo"])["High"].mean().plot.pie()
# Out:
# <AxesSubplot:ylabel='High'>

# %%
df.boxplot(column="Volume")
# Out:
# <AxesSubplot:>

# %%
## Bigote de abajo: max{minimo, Q1-1,5RI}
### la primera linea azul Q1
### la linea verde Mediana Q2
### la linea azul de arriba Q3
## Bigote de arriba: min{maximo, Q3+1,5RI}

# %%
df.boxplot(column="Volume",by="Anyo");

# %%
df["volumen_escala"]=np.log(df["Volume"])
df.boxplot(column="volumen_escala",by="Anyo");

# %%
df.corr()
# Out:
#                               High       Low      Open     Close    Volume  \
# High                      1.000000  0.999856  0.999923  0.999904 -0.264460
# Low                       0.999856  1.000000  0.999890  0.999909 -0.267341
# Open                      0.999923  0.999890  1.000000  0.999822 -0.265561
# Close                     0.999904  0.999909  0.999822  1.000000 -0.265916
# Volume                   -0.264460 -0.267341 -0.265561 -0.265916  1.000000
# Adj Close                 0.999280  0.999158  0.999129  0.999319 -0.268136
# Variacion_High            0.013598  0.013644  0.012422  0.014685  0.039013
# Medias_Moviles_High       0.999701  0.999507  0.999634  0.999542 -0.264635
# Diferencia_Volumen        0.000241 -0.000710 -0.000081 -0.000340  0.339469
# tendecia                  0.998965  0.998789  0.998832  0.998883 -0.267864
# Medias_Moviles_Adj_Close  0.999188  0.998961  0.999078  0.999041 -0.268046
# volumen_escala           -0.378395 -0.382591 -0.380040 -0.380577  0.873017
#
#                           Adj Close  Variacion_High  Medias_Moviles_High  \
# High                       0.999280        0.013598             0.999701
# Low                        0.999158        0.013644             0.999507
# Open                       0.999129        0.012422             0.999634
# Close                      0.999319        0.014685             0.999542
# Volume                    -0.268136        0.039013            -0.264635
# Adj Close                  1.000000        0.014786             0.998862
# Variacion_High             0.014786        1.000000             0.007619
# Medias_Moviles_High        0.998862        0.007619             1.000000
# Diferencia_Volumen        -0.000319        0.136957             0.000050
# tendecia                   0.999566        0.010781             0.998978
# Medias_Moviles_Adj_Close   0.999671        0.008614             0.999338
# volumen_escala            -0.385131        0.068437            -0.378786
#
#                           Diferencia_Volumen  tendecia  \
# High                                0.000241  0.998965
# Low                                -0.000710  0.998789
# Open                               -0.000081  0.998832
# Close                              -0.000340  0.998883
# Volume                              0.339469 -0.267864
# Adj Close                          -0.000319  0.999566
# Variacion_High                      0.136957  0.010781
# Medias_Moviles_High                 0.000050  0.998978
# Diferencia_Volumen                  1.000000 -0.000092
# tendecia                           -0.000092  1.000000
# Medias_Moviles_Adj_Close            0.000068  0.999703
# volumen_escala                      0.187394 -0.384863
#
#                           Medias_Moviles_Adj_Close  volumen_escala
# High                                      0.999188       -0.378395
# Low                                       0.998961       -0.382591
# Open                                      0.999078       -0.380040
# Close                                     0.999041       -0.380577
# Volume                                   -0.268046        0.873017
# Adj Close                                 0.999671       -0.385131
# Variacion_High                            0.008614        0.068437
# Medias_Moviles_High                       0.999338       -0.378786
# Diferencia_Volumen                        0.000068        0.187394
# tendecia                                  0.999703       -0.384863
# Medias_Moviles_Adj_Close                  1.000000       -0.385040
# volumen_escala                           -0.385040        1.000000

# %%
plt.scatter(df["High"],df["Low"]);
plt.title("Relación entre La varaible Hig y la variable Low");
plt.xlabel("Precio High")
plt.ylabel("Precio Low")
# Out:
# Text(0, 0.5, 'Precio Low')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.scatter(df["High"],df["Low"]);
plt.title("Relación entre La varaible Hig y la variable Low");
plt.xlabel("Precio High")
plt.ylabel("Precio Low")
# Out:
# Text(0, 0.5, 'Precio Low')

# %%
plt.style.use('ggplot')
plt.hist(df["High"]);
plt.title("Relación entre La varaible Hig y la variable Low");
plt.xlabel("Precio High")
plt.ylabel("Precio Low")
# Out:
# Text(0, 0.5, 'Precio Low')

# %%
df.boxplot(column="volumen_escala",by="Anyo");

# %%
import seaborn as sns

# %%
sns.lmplot(x="High",y="Volume",data=df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 import altair
#
# ModuleNotFoundError: No module named 'altair'

# %%
# pip install altair
# Out:
# Collecting altair
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (4.4.0)
# Requirement already satisfied: numpy in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (1.21.5)
# Requirement already satisfied: entrypoints in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (0.4)
# Requirement already satisfied: pandas>=0.18 in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: toolz in c:\users\daniel montes\anaconda3\lib\site-packages (from altair) (0.11.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\daniel montes\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\daniel montes\anaconda3\lib\site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\daniel montes\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2.8.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pytz>=2020.1 in c:\users\daniel montes\anaconda3\lib\site-packages (from pandas>=0.18->altair) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\daniel montes\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\daniel montes\anaconda3\lib\site-packages (from jinja2->altair) (2.0.1)
# Installing collected packages: altair
# Successfully installed altair-4.2.0

# %%
from altair import Chart, Color, Scale

# %%
diagrama=Chart(df.loc["2000-01-01":"2003-01-01",])

# %%
df.loc["2000-01-01":"2001-01-01",]
# Out:
#                 High       Low      Open     Close       Volume  Adj Close  \
# Date
# 2000-01-03  1.004464  0.907924  0.936384  0.999442  535796800.0   0.853356
# 2000-01-04  0.987723  0.903460  0.966518  0.915179  512377600.0   0.781409
# 2000-01-05  0.987165  0.919643  0.926339  0.928571  778321600.0   0.792844
# 2000-01-06  0.955357  0.848214  0.947545  0.848214  767972800.0   0.724232
# 2000-01-07  0.901786  0.852679  0.861607  0.888393  460734400.0   0.758538
# ...              ...       ...       ...       ...          ...        ...
# 2000-12-22  0.267857  0.252232  0.252232  0.267857  318052000.0   0.228705
# 2000-12-26  0.267857  0.254464  0.265625  0.262277  216815200.0   0.223940
# 2000-12-27  0.264509  0.253348  0.256138  0.264509  325466400.0   0.225846
# 2000-12-28  0.266741  0.255580  0.256696  0.264509  305177600.0   0.225846
# 2000-12-29  0.267857  0.258929  0.262277  0.265625  630336000.0   0.226799
#
#             Variacion_High  Medias_Moviles_High  Diferencia_Volumen  tendecia  \
# Date
# 2000-01-03        0.093560             0.930915         371985600.0  0.768933
# 2000-01-04       -0.016667             0.950558         -23419200.0  0.768707
# 2000-01-05       -0.000565             0.965513         265944000.0  0.768698
# 2000-01-06       -0.032222             0.970647         -10348800.0  0.768971
# 2000-01-07       -0.056074             0.967299        -307238400.0  0.769609
# ...                    ...                  ...                 ...       ...
# 2000-12-22        0.000000             0.266071         -48792800.0  0.228998
# 2000-12-26        0.000000             0.267411        -101236800.0  0.230428
# 2000-12-27       -0.012499             0.265848         108651200.0  0.232260
# 2000-12-28        0.008438             0.266964         -20288800.0  0.234471
# 2000-12-29        0.004184             0.266964         325158400.0  0.237035
#
#             Medias_Moviles_Adj_Close  Anyo  volumen_escala
# Date
# 2000-01-03                  0.783600  2000       20.099266
# 2000-01-04                  0.790176  2000       20.054572
# 2000-01-05                  0.795226  2000       20.472650
# 2000-01-06                  0.787126  2000       20.459265
# 2000-01-07                  0.782076  2000       19.948332
# ...                              ...   ...             ...
# 2000-12-22                  0.218604  2000       19.577725
# 2000-12-26                  0.219938  2000       19.194556
# 2000-12-27                  0.222416  2000       19.600770
# 2000-12-28                  0.223750  2000       19.536404
# 2000-12-29                  0.226227  2000       20.261764
#
# [252 rows x 13 columns]

# %%
diagrama.mark_point().encode(x="High",y="Low")
# Out:
# alt.Chart(...)

# %%
escala=Scale(range=['#996666', '#b34d4d', '#cc3333','#e61919','#ff0000'])
diagrama.mark_point().encode(x="High",y="Low",color=Color("Anyo",scale=escala))
# Out:
# alt.Chart(...)

# %%
df["High"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
